# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)

# %%
df_1 = pd.read_csv("world-data-2023_part1_pair.csv", index_col=0)
df_1.head()
# Out:
#        country density abbreviation  agriculturalland   landarea  \
# 0  Afghanistan      60           AF              58.1    652,230
# 1      Albania     105           AL              43.1     28,748
# 2      Algeria      18           DZ              17.4  2,381,741
# 3      Andorra     164           AD              40.0        468
# 4       Angola      26           AO              47.5  1,246,700
#
#   armedforcessize  birthrate  callingcode capital/majorcity co2-emissions  \
# 0         323,000      32.49         93.0             Kabul         8,672
# 1           9,000      11.78        355.0            Tirana         4,536
# 2         317,000      24.28        213.0           Algiers       150,006
# 3             NaN       7.20        376.0  Andorra la Vella           469
# 4         117,000      40.73        244.0            Luanda        34,693
#
#       cpi  cpichange currency-code  fertilityrate  forestedarea  \
# ...

# %% [markdown]
# Las columnas land_area, armed_forces_size, co2-emissions, gdp, population, urban_population, latitude, longitude, density, cpi son de tipo object pero en realidad deberían ser numéricas. Crea una función que nos permita cambiar el tipo de dato de estas columnas al que le corresponde.

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            195 non-null    object
#  1   density                            195 non-null    object
#  2   abbreviation                       188 non-null    object
#  3   agriculturalland                   188 non-null    float64
#  4   landarea                           194 non-null    object
#  5   armedforcessize                    171 non-null    object
#  6   birthrate                          189 non-null    float64
#  7   callingcode                        194 non-null    float64
#  8   capital/majorcity                  192 non-null    object
#  9   co2-emissions                      188 non-null    object
#  10  cpi                                178 non-null    object
# ...

# %%
def cambiar_comas(cadena):
     cadena2= cadena.replace(",", ".",1)
     
     try:
          return float(cadena2)
    
     except:
          return np.nan

# %%
df_1["landarea"]=df_1["landarea"].apply(cambiar_comas)
df_1.head(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1874/2821325410.py in <module>
# ----> 1 df_1["landarea"]=df_1["landarea"].apply(cambiar_comas)
#       2 df_1.head(3)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwargs)
#    4355         dtype: float64
#    4356         """
# -> 4357         return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#    4358
#    4359     def _reduce(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply(self)
#    1041             return self.apply_str()
#    1042
# -> 1043         return self.apply_standard()
#    1044
#    1045     def agg(self):
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/apply.py in apply_standard(self)
#    1096                 # List[Union[Callable[..., Any], str]]]]]"; expected
# ...

# %%
lista_columnas = ["landarea", "armedforcessize", "co2-emissions", "gdp", "population", "urban_population", "lat", "long", "density", "cpi"]

# %%
for col in lista_columnas:
    df_1[col] = df_1[col].apply(cambiar_comas)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 195 entries, 0 to 194
# Data columns (total 35 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   country                            195 non-null    object
#  1   density                            195 non-null    float64
#  2   abbreviation                       188 non-null    object
#  3   agriculturalland                   188 non-null    float64
#  4   landarea                           0 non-null      float64
#  5   armedforcessize                    0 non-null      float64
#  6   birthrate                          189 non-null    float64
#  7   callingcode                        194 non-null    float64
#  8   capital/majorcity                  192 non-null    object
#  9   co2-emissions                      0 non-null      float64
#  10  cpi                                175 non-null    float64
# ...
